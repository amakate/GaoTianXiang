# %% [markdown]
# <a href="https://colab.research.google.com/github/amakate/GaoTianXiang/blob/master/multibeam_heatmap_GTX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 16匹
import numpy as np
import pyedflib
import matplotlib.pyplot as plt
import numpy as np
from numpy.fft import fftn, ifftn, fftfreq
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import sqlalchemy
from matplotlib.ticker import ScalarFormatter
import sqlalchemy
from matplotlib.ticker import ScalarFormatter
from scipy.fftpack import fft, ifft
import os
import glob
from sklearn.preprocessing import MinMaxScaler


'''
fill the number of days you want to polt
for example :
firth_day = 1
last_day = 3
your_sampling_period = 2
heatmap_period_you_want = 60
numbers_of_flies = 16
heatmap_vmax = 200
heatmap_vmin = 1
'''


firth_day = 1
last_day = 4
your_sampling_period = 2
heatmap_period_you_want = 60
numbers_of_flies = 16
heatmap_vmax = 80
heatmap_vmin = 1
the_numbers_of_the_channels_you_want_delete = 0

'''
if you don't want delete any channels,
you should not fill thoes followig equals
'''

the_channels_you_want_plot_1 = 1
the_channels_you_want_plot_2 = 2
the_channels_you_want_plot_3 = 3
the_channels_you_want_plot_4 = 4
the_channels_you_want_plot_5 = 5
the_channels_you_want_plot_6 = 6
the_channels_you_want_plot_7 = 7
the_channels_you_want_plot_8 = 8
the_channels_you_want_plot_9 = 9
the_channels_you_want_plot_10 = 10
the_channels_you_want_plot_11 = 11
the_channels_you_want_plot_12 = 12
the_channels_you_want_plot_13 = 13
the_channels_you_want_plot_14 = 14
the_channels_you_want_plot_15 = 15
the_channels_you_want_plot_16 = 16

##################################################################################################################################################################################################################
##################################################################################################################################################################################################################
##################################################################################################################################################################################################################

whole_day_seconds = 60*60*24
whole_day_samples = whole_day_seconds/your_sampling_period 
heat = heatmap_period_you_want/your_sampling_period


delta_day =last_day - firth_day
text_list = glob.glob('*.txt')
print(text_list)
print(text_list[0])
dataraw = pd.read_table(text_list[0],header=None)



def raw_slice(dataraw):
    global kara_list
    kara_list = []
    if the_numbers_of_the_channels_you_want_delete == 0:
      for i in range(int(whole_day_samples*(firth_day-1))+1,int(whole_day_samples*(last_day)+1),1): 
              datai = dataraw.iloc[i*17-1,10:26]
              print(datai)
              datai_np = datai.values.tolist()
               #list_sum = data_sum.values.tolist()
               #print(list_sum)
              kara_list = kara_list + datai_np 
    else:
      for i in range(int(whole_day_samples*(firth_day-1)),int(whole_day_samples*(last_day)+1),1):
      #for i in range(1,31,1):
          
          datai = dataraw.iloc[i*17-1,[int(the_channels_you_want_plot_1 + 9),
                                            int(the_channels_you_want_plot_2 + 9),
                                            int(the_channels_you_want_plot_3 + 9),
                                            int(the_channels_you_want_plot_4 + 9),
                                            int(the_channels_you_want_plot_5 + 9),
                                            int(the_channels_you_want_plot_6 + 9),
                                            int(the_channels_you_want_plot_7 + 9),
                                            int(the_channels_you_want_plot_8 + 9),
                                            int(the_channels_you_want_plot_9 + 9)，
                                            int(the_channels_you_want_plot_10 + 9),
                                            int(the_channels_you_want_plot_11 + 9)，
                                            int(the_channels_you_want_plot_12 + 9),  
                                            int(the_channels_you_want_plot_13 + 9)，
                                            int(the_channels_you_want_plot_14 + 9)， 
                                            int(the_channels_you_want_plot_15 + 9)， 
                                            int(the_channels_you_want_plot_16 + 9)，                ]]
               
          print(datai)
          datai_np = datai.values.tolist()
               #list_sum = data_sum.values.tolist()
               #print(list_sum)
          kara_list = kara_list + datai_np 
   
    
      print(kara_list)    
      arr_np = np.array(kara_list)
      kara_list_len = len(kara_list)
      print(kara_list_len)
      global kara_list_re
      kara_list_re = arr_np.reshape([int(kara_list_len/int(16-the_numbers_of_the_channels_you_want_delete)),
                                     int(16-the_numbers_of_the_channels_you_want_delete)])
      return kara_list_re

re = raw_slice(dataraw)





shushu = []


def re_counts(re):
#for j in range(1,1440+1,1):
    for j in range(1,int((delta_day+1)*whole_day_seconds/heatmap_period_you_want+1),1):
        npj = re[int((j-1)*heat):int(j*heat),:]
        print(npj)
    
        c1 = np.count_nonzero(npj == 1, axis=0)
        c2 = np.count_nonzero(npj == 2, axis=0)
        c3 = np.count_nonzero(npj == 3, axis=0)
        c4 = np.count_nonzero(npj == 4, axis=0)
        c5 = np.count_nonzero(npj == 5, axis=0)
        c6 = np.count_nonzero(npj == 6, axis=0)
        c7 = np.count_nonzero(npj == 7, axis=0)
        c8 = np.count_nonzero(npj == 8, axis=0)
        c9 = np.count_nonzero(npj == 9, axis=0)
        c10 = np.count_nonzero(npj == 10, axis=0)
        c11 = np.count_nonzero(npj == 11, axis=0)
        c12 = np.count_nonzero(npj == 12, axis=0)
        c13 = np.count_nonzero(npj == 13, axis=0)
        c14 = np.count_nonzero(npj == 14, axis=0)
        c15 = np.count_nonzero(npj == 15, axis=0)
        c16 = np.count_nonzero(npj == 16, axis=0)
        c17 = np.count_nonzero(npj == 17, axis=0)
    

    
        shushu.extend([c1.sum(),c2.sum(),c3.sum(),
                       c4.sum(),c5.sum(),c6.sum(),       
                       c7.sum(),c8.sum(),c9.sum(),  
                       c10.sum(),c11.sum(),c12.sum(), 
                      c13.sum(),c14.sum(),c15.sum(), 
                      c16.sum(),c17.sum()
                   
                       ])
        print(shushu)
 
    
    print(shushu)
    global shushu_np,shushu_np_re,shushu_np_re_df
    shushu_np = np.array(shushu)
    shushu_np_re = shushu_np.reshape([int(len(shushu_np)/17),17])
    #shushu_np_re = shushu_np.reshape([17,int(len(shushu_np)/17)])
    print(shushu_np_re)
    shushu_np_re_df = pd.DataFrame(shushu_np_re)
    return(shushu_np_re_df)

heatmap = re_counts(re)







#re = raw_slice(dataraw)



fig=plt.figure(figsize=(24,8))
sns.heatmap(heatmap.T,vmin=heatmap_vmin,vmax=heatmap_vmax,cmap="jet")
plt.savefig('multi__'+'.png')

# %%
# 15匹
import numpy as np
import pyedflib
import matplotlib.pyplot as plt
import numpy as np
from numpy.fft import fftn, ifftn, fftfreq
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import sqlalchemy
from matplotlib.ticker import ScalarFormatter
import sqlalchemy
from matplotlib.ticker import ScalarFormatter
from scipy.fftpack import fft, ifft
import os
import glob
from sklearn.preprocessing import MinMaxScaler


'''
fill the number of days you want to polt
for example :
firth_day = 1
last_day = 3
your_sampling_period = 2
heatmap_period_you_want = 60
numbers_of_flies = 16
heatmap_vmax = 200
heatmap_vmin = 1
'''


firth_day = 1
last_day = 4
your_sampling_period = 2
heatmap_period_you_want = 60
numbers_of_flies = 16
heatmap_vmax = 80
heatmap_vmin = 1
the_numbers_of_the_channels_you_want_delete = 1

'''
if you don't want delete any channels,
you should not fill thoes followig equals
'''

the_channels_you_want_plot_1 = 
the_channels_you_want_plot_2 = 
the_channels_you_want_plot_3 = 
the_channels_you_want_plot_4 = 
the_channels_you_want_plot_5 =  
the_channels_you_want_plot_6 = 
the_channels_you_want_plot_7 = 
the_channels_you_want_plot_8 = 
the_channels_you_want_plot_9 = 
the_channels_you_want_plot_10 = 
the_channels_you_want_plot_11 = 
the_channels_you_want_plot_12 = 
the_channels_you_want_plot_13 =
the_channels_you_want_plot_14 =
the_channels_you_want_plot_15 =


##################################################################################################################################################################################################################
##################################################################################################################################################################################################################
##################################################################################################################################################################################################################

whole_day_seconds = 60*60*24
whole_day_samples = whole_day_seconds/your_sampling_period 
heat = heatmap_period_you_want/your_sampling_period


delta_day =last_day - firth_day
text_list = glob.glob('*.txt')
print(text_list)
print(text_list[0])
dataraw = pd.read_table(text_list[0],header=None)



def raw_slice(dataraw):
    global kara_list
    kara_list = []
    if the_numbers_of_the_channels_you_want_delete == 0:
      for i in range(int(whole_day_samples*(firth_day-1))+1,int(whole_day_samples*(last_day)+1),1): 
              datai = dataraw.iloc[i*17-1,10:26]
              print(datai)
              datai_np = datai.values.tolist()
               #list_sum = data_sum.values.tolist()
               #print(list_sum)
              kara_list = kara_list + datai_np 
    else:
      for i in range(int(whole_day_samples*(firth_day-1)),int(whole_day_samples*(last_day)+1),1):
      #for i in range(1,31,1):
          
          datai = dataraw.iloc[i*17-1,[int(the_channels_you_want_plot_1 + 9),
                                            int(the_channels_you_want_plot_2 + 9),
                                            int(the_channels_you_want_plot_3 + 9),
                                            int(the_channels_you_want_plot_4 + 9),
                                            int(the_channels_you_want_plot_5 + 9),
                                            int(the_channels_you_want_plot_6 + 9),
                                            int(the_channels_you_want_plot_7 + 9),
                                            int(the_channels_you_want_plot_8 + 9),
                                            int(the_channels_you_want_plot_9 + 9)，
                                            int(the_channels_you_want_plot_10 + 9),
                                            int(the_channels_you_want_plot_11 + 9)，
                                            int(the_channels_you_want_plot_12 + 9),  
                                            int(the_channels_you_want_plot_13 + 9)，
                                            int(the_channels_you_want_plot_14 + 9)， 
                                            int(the_channels_you_want_plot_15 + 9)，                 ]]
               
          print(datai)
          datai_np = datai.values.tolist()
               #list_sum = data_sum.values.tolist()
               #print(list_sum)
          kara_list = kara_list + datai_np 
   
    
      print(kara_list)    
      arr_np = np.array(kara_list)
      kara_list_len = len(kara_list)
      print(kara_list_len)
      global kara_list_re
      kara_list_re = arr_np.reshape([int(kara_list_len/int(16-the_numbers_of_the_channels_you_want_delete)),
                                     int(16-the_numbers_of_the_channels_you_want_delete)])
      return kara_list_re

re = raw_slice(dataraw)





shushu = []


def re_counts(re):
#for j in range(1,1440+1,1):
    for j in range(1,int((delta_day+1)*whole_day_seconds/heatmap_period_you_want+1),1):
        npj = re[int((j-1)*heat):int(j*heat),:]
        print(npj)
    
        c1 = np.count_nonzero(npj == 1, axis=0)
        c2 = np.count_nonzero(npj == 2, axis=0)
        c3 = np.count_nonzero(npj == 3, axis=0)
        c4 = np.count_nonzero(npj == 4, axis=0)
        c5 = np.count_nonzero(npj == 5, axis=0)
        c6 = np.count_nonzero(npj == 6, axis=0)
        c7 = np.count_nonzero(npj == 7, axis=0)
        c8 = np.count_nonzero(npj == 8, axis=0)
        c9 = np.count_nonzero(npj == 9, axis=0)
        c10 = np.count_nonzero(npj == 10, axis=0)
        c11 = np.count_nonzero(npj == 11, axis=0)
        c12 = np.count_nonzero(npj == 12, axis=0)
        c13 = np.count_nonzero(npj == 13, axis=0)
        c14 = np.count_nonzero(npj == 14, axis=0)
        c15 = np.count_nonzero(npj == 15, axis=0)
        c16 = np.count_nonzero(npj == 16, axis=0)
        c17 = np.count_nonzero(npj == 17, axis=0)
    

    
        shushu.extend([c1.sum(),c2.sum(),c3.sum(),
                       c4.sum(),c5.sum(),c6.sum(),       
                       c7.sum(),c8.sum(),c9.sum(),  
                       c10.sum(),c11.sum(),c12.sum(), 
                      c13.sum(),c14.sum(),c15.sum(), 
                      c16.sum(),c17.sum()
                   
                       ])
        print(shushu)
 
    
    print(shushu)
    global shushu_np,shushu_np_re,shushu_np_re_df
    shushu_np = np.array(shushu)
    shushu_np_re = shushu_np.reshape([int(len(shushu_np)/17),17])
    #shushu_np_re = shushu_np.reshape([17,int(len(shushu_np)/17)])
    print(shushu_np_re)
    shushu_np_re_df = pd.DataFrame(shushu_np_re)
    return(shushu_np_re_df)

heatmap = re_counts(re)







#re = raw_slice(dataraw)



fig=plt.figure(figsize=(24,8))
sns.heatmap(heatmap.T,vmin=heatmap_vmin,vmax=heatmap_vmax,cmap="jet")
plt.savefig('multi__'+'.png')

# %%
##14匹
import numpy as np
import pyedflib
import matplotlib.pyplot as plt
import numpy as np
from numpy.fft import fftn, ifftn, fftfreq
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import sqlalchemy
from matplotlib.ticker import ScalarFormatter
import sqlalchemy
from matplotlib.ticker import ScalarFormatter
from scipy.fftpack import fft, ifft
import os
import glob
from sklearn.preprocessing import MinMaxScaler


'''
fill the number of days you want to polt
for example :
firth_day = 1
last_day = 3
your_sampling_period = 2
heatmap_period_you_want = 60
numbers_of_flies = 16
heatmap_vmax = 200
heatmap_vmin = 1
'''


firth_day = 1
last_day = 4
your_sampling_period = 2
heatmap_period_you_want = 60
numbers_of_flies = 16
heatmap_vmax = 80
heatmap_vmin = 1
the_numbers_of_the_channels_you_want_delete = 2

'''
if you don't want delete any channels,
you should not fill thoes followig equals
'''

the_channels_you_want_plot_1 = 
the_channels_you_want_plot_2 = 
the_channels_you_want_plot_3 = 
the_channels_you_want_plot_4 = 
the_channels_you_want_plot_5 =  
the_channels_you_want_plot_6 = 
the_channels_you_want_plot_7 = 
the_channels_you_want_plot_8 = 
the_channels_you_want_plot_9 = 
the_channels_you_want_plot_10 = 
the_channels_you_want_plot_11 = 
the_channels_you_want_plot_12 = 
the_channels_you_want_plot_13 =
the_channels_you_want_plot_14 =

##################################################################################################################################################################################################################
##################################################################################################################################################################################################################
##################################################################################################################################################################################################################

whole_day_seconds = 60*60*24
whole_day_samples = whole_day_seconds/your_sampling_period 
heat = heatmap_period_you_want/your_sampling_period


delta_day =last_day - firth_day
text_list = glob.glob('*.txt')
print(text_list)
print(text_list[0])
dataraw = pd.read_table(text_list[0],header=None)



def raw_slice(dataraw):
    global kara_list
    kara_list = []
    if the_numbers_of_the_channels_you_want_delete == 0:
      for i in range(int(whole_day_samples*(firth_day-1))+1,int(whole_day_samples*(last_day)+1),1): 
              datai = dataraw.iloc[i*17-1,10:26]
              print(datai)
              datai_np = datai.values.tolist()
               #list_sum = data_sum.values.tolist()
               #print(list_sum)
              kara_list = kara_list + datai_np 
    else:
      for i in range(int(whole_day_samples*(firth_day-1)),int(whole_day_samples*(last_day)+1),1):
      #for i in range(1,31,1):
          
          datai = dataraw.iloc[i*17-1,[int(the_channels_you_want_plot_1 + 9),
                                            int(the_channels_you_want_plot_2 + 9),
                                            int(the_channels_you_want_plot_3 + 9),
                                            int(the_channels_you_want_plot_4 + 9),
                                            int(the_channels_you_want_plot_5 + 9),
                                            int(the_channels_you_want_plot_6 + 9),
                                            int(the_channels_you_want_plot_7 + 9),
                                            int(the_channels_you_want_plot_8 + 9),
                                            int(the_channels_you_want_plot_9 + 9)，
                                            int(the_channels_you_want_plot_10 + 9),
                                            int(the_channels_you_want_plot_11 + 9)，
                                            int(the_channels_you_want_plot_12 + 9),  
                                            int(the_channels_you_want_plot_13 + 9)，
                                            int(the_channels_you_want_plot_14 + 9)，                        ]]
               
          print(datai)
          datai_np = datai.values.tolist()
               #list_sum = data_sum.values.tolist()
               #print(list_sum)
          kara_list = kara_list + datai_np 
   
    
      print(kara_list)    
      arr_np = np.array(kara_list)
      kara_list_len = len(kara_list)
      print(kara_list_len)
      global kara_list_re
      kara_list_re = arr_np.reshape([int(kara_list_len/int(16-the_numbers_of_the_channels_you_want_delete)),
                                     int(16-the_numbers_of_the_channels_you_want_delete)])
      return kara_list_re

re = raw_slice(dataraw)





shushu = []


def re_counts(re):
#for j in range(1,1440+1,1):
    for j in range(1,int((delta_day+1)*whole_day_seconds/heatmap_period_you_want+1),1):
        npj = re[int((j-1)*heat):int(j*heat),:]
        print(npj)
    
        c1 = np.count_nonzero(npj == 1, axis=0)
        c2 = np.count_nonzero(npj == 2, axis=0)
        c3 = np.count_nonzero(npj == 3, axis=0)
        c4 = np.count_nonzero(npj == 4, axis=0)
        c5 = np.count_nonzero(npj == 5, axis=0)
        c6 = np.count_nonzero(npj == 6, axis=0)
        c7 = np.count_nonzero(npj == 7, axis=0)
        c8 = np.count_nonzero(npj == 8, axis=0)
        c9 = np.count_nonzero(npj == 9, axis=0)
        c10 = np.count_nonzero(npj == 10, axis=0)
        c11 = np.count_nonzero(npj == 11, axis=0)
        c12 = np.count_nonzero(npj == 12, axis=0)
        c13 = np.count_nonzero(npj == 13, axis=0)
        c14 = np.count_nonzero(npj == 14, axis=0)
        c15 = np.count_nonzero(npj == 15, axis=0)
        c16 = np.count_nonzero(npj == 16, axis=0)
        c17 = np.count_nonzero(npj == 17, axis=0)
    

    
        shushu.extend([c1.sum(),c2.sum(),c3.sum(),
                       c4.sum(),c5.sum(),c6.sum(),       
                       c7.sum(),c8.sum(),c9.sum(),  
                       c10.sum(),c11.sum(),c12.sum(), 
                      c13.sum(),c14.sum(),c15.sum(), 
                      c16.sum(),c17.sum()
                   
                       ])
        print(shushu)
 
    
    print(shushu)
    global shushu_np,shushu_np_re,shushu_np_re_df
    shushu_np = np.array(shushu)
    shushu_np_re = shushu_np.reshape([int(len(shushu_np)/17),17])
    #shushu_np_re = shushu_np.reshape([17,int(len(shushu_np)/17)])
    print(shushu_np_re)
    shushu_np_re_df = pd.DataFrame(shushu_np_re)
    return(shushu_np_re_df)

heatmap = re_counts(re)







#re = raw_slice(dataraw)



fig=plt.figure(figsize=(24,8))
sns.heatmap(heatmap.T,vmin=heatmap_vmin,vmax=heatmap_vmax,cmap="jet")
plt.savefig('multi__'+'.png')

# %%
##13匹
import numpy as np
import pyedflib
import matplotlib.pyplot as plt
import numpy as np
from numpy.fft import fftn, ifftn, fftfreq
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import sqlalchemy
from matplotlib.ticker import ScalarFormatter
import sqlalchemy
from matplotlib.ticker import ScalarFormatter
from scipy.fftpack import fft, ifft
import os
import glob
from sklearn.preprocessing import MinMaxScaler


'''
fill the number of days you want to polt
for example :
firth_day = 1
last_day = 3
your_sampling_period = 2
heatmap_period_you_want = 60
numbers_of_flies = 16
heatmap_vmax = 200
heatmap_vmin = 1
'''


firth_day = 1
last_day = 4
your_sampling_period = 2
heatmap_period_you_want = 60
numbers_of_flies = 16
heatmap_vmax = 80
heatmap_vmin = 1
the_numbers_of_the_channels_you_want_delete = 3

'''
if you don't want delete any channels,
you should not fill thoes followig equals
'''

the_channels_you_want_plot_1 = 
the_channels_you_want_plot_2 = 
the_channels_you_want_plot_3 = 
the_channels_you_want_plot_4 = 
the_channels_you_want_plot_5 =  
the_channels_you_want_plot_6 = 
the_channels_you_want_plot_7 = 
the_channels_you_want_plot_8 = 
the_channels_you_want_plot_9 = 
the_channels_you_want_plot_10 = 
the_channels_you_want_plot_11 = 
the_channels_you_want_plot_12 = 
the_channels_you_want_plot_13 =

##################################################################################################################################################################################################################
##################################################################################################################################################################################################################
##################################################################################################################################################################################################################

whole_day_seconds = 60*60*24
whole_day_samples = whole_day_seconds/your_sampling_period 
heat = heatmap_period_you_want/your_sampling_period


delta_day =last_day - firth_day
text_list = glob.glob('*.txt')
print(text_list)
print(text_list[0])
dataraw = pd.read_table(text_list[0],header=None)



def raw_slice(dataraw):
    global kara_list
    kara_list = []
    if the_numbers_of_the_channels_you_want_delete == 0:
      for i in range(int(whole_day_samples*(firth_day-1))+1,int(whole_day_samples*(last_day)+1),1): 
              datai = dataraw.iloc[i*17-1,10:26]
              print(datai)
              datai_np = datai.values.tolist()
               #list_sum = data_sum.values.tolist()
               #print(list_sum)
              kara_list = kara_list + datai_np 
    else:
      for i in range(int(whole_day_samples*(firth_day-1)),int(whole_day_samples*(last_day)+1),1):
      #for i in range(1,31,1):
          
          datai = dataraw.iloc[i*17-1,[int(the_channels_you_want_plot_1 + 9),
                                            int(the_channels_you_want_plot_2 + 9),
                                            int(the_channels_you_want_plot_3 + 9),
                                            int(the_channels_you_want_plot_4 + 9),
                                            int(the_channels_you_want_plot_5 + 9),
                                            int(the_channels_you_want_plot_6 + 9),
                                            int(the_channels_you_want_plot_7 + 9),
                                            int(the_channels_you_want_plot_8 + 9),
                                            int(the_channels_you_want_plot_9 + 9)，
                                            int(the_channels_you_want_plot_10 + 9),
                                            int(the_channels_you_want_plot_11 + 9)，
                                            int(the_channels_you_want_plot_12 + 9),  
                                            int(the_channels_you_want_plot_13 + 9) ]]
               
          print(datai)
          datai_np = datai.values.tolist()
               #list_sum = data_sum.values.tolist()
               #print(list_sum)
          kara_list = kara_list + datai_np 
   
    
      print(kara_list)    
      arr_np = np.array(kara_list)
      kara_list_len = len(kara_list)
      print(kara_list_len)
      global kara_list_re
      kara_list_re = arr_np.reshape([int(kara_list_len/int(16-the_numbers_of_the_channels_you_want_delete)),
                                     int(16-the_numbers_of_the_channels_you_want_delete)])
      return kara_list_re

re = raw_slice(dataraw)





shushu = []


def re_counts(re):
#for j in range(1,1440+1,1):
    for j in range(1,int((delta_day+1)*whole_day_seconds/heatmap_period_you_want+1),1):
        npj = re[int((j-1)*heat):int(j*heat),:]
        print(npj)
    
        c1 = np.count_nonzero(npj == 1, axis=0)
        c2 = np.count_nonzero(npj == 2, axis=0)
        c3 = np.count_nonzero(npj == 3, axis=0)
        c4 = np.count_nonzero(npj == 4, axis=0)
        c5 = np.count_nonzero(npj == 5, axis=0)
        c6 = np.count_nonzero(npj == 6, axis=0)
        c7 = np.count_nonzero(npj == 7, axis=0)
        c8 = np.count_nonzero(npj == 8, axis=0)
        c9 = np.count_nonzero(npj == 9, axis=0)
        c10 = np.count_nonzero(npj == 10, axis=0)
        c11 = np.count_nonzero(npj == 11, axis=0)
        c12 = np.count_nonzero(npj == 12, axis=0)
        c13 = np.count_nonzero(npj == 13, axis=0)
        c14 = np.count_nonzero(npj == 14, axis=0)
        c15 = np.count_nonzero(npj == 15, axis=0)
        c16 = np.count_nonzero(npj == 16, axis=0)
        c17 = np.count_nonzero(npj == 17, axis=0)
    

    
        shushu.extend([c1.sum(),c2.sum(),c3.sum(),
                       c4.sum(),c5.sum(),c6.sum(),       
                       c7.sum(),c8.sum(),c9.sum(),  
                       c10.sum(),c11.sum(),c12.sum(), 
                      c13.sum(),c14.sum(),c15.sum(), 
                      c16.sum(),c17.sum()
                   
                       ])
        print(shushu)
 
    
    print(shushu)
    global shushu_np,shushu_np_re,shushu_np_re_df
    shushu_np = np.array(shushu)
    shushu_np_re = shushu_np.reshape([int(len(shushu_np)/17),17])
    #shushu_np_re = shushu_np.reshape([17,int(len(shushu_np)/17)])
    print(shushu_np_re)
    shushu_np_re_df = pd.DataFrame(shushu_np_re)
    return(shushu_np_re_df)

heatmap = re_counts(re)







#re = raw_slice(dataraw)



fig=plt.figure(figsize=(24,8))
sns.heatmap(heatmap.T,vmin=heatmap_vmin,vmax=heatmap_vmax,cmap="jet")
plt.savefig('multi__'+'.png')

# %%
##12匹
import numpy as np
import pyedflib
import matplotlib.pyplot as plt
import numpy as np
from numpy.fft import fftn, ifftn, fftfreq
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import sqlalchemy
from matplotlib.ticker import ScalarFormatter
import sqlalchemy
from matplotlib.ticker import ScalarFormatter
from scipy.fftpack import fft, ifft
import os
import glob
from sklearn.preprocessing import MinMaxScaler


'''
fill the number of days you want to polt
for example :
firth_day = 1
last_day = 3
your_sampling_period = 2
heatmap_period_you_want = 60
numbers_of_flies = 16
heatmap_vmax = 200
heatmap_vmin = 1
'''


firth_day = 1
last_day = 4
your_sampling_period = 2
heatmap_period_you_want = 60
numbers_of_flies = 16
heatmap_vmax = 80
heatmap_vmin = 1
the_numbers_of_the_channels_you_want_delete = 4

'''
if you don't want delete any channels,
you should not fill thoes followig equals
'''

the_channels_you_want_plot_1 = 
the_channels_you_want_plot_2 = 
the_channels_you_want_plot_3 = 
the_channels_you_want_plot_4 = 
the_channels_you_want_plot_5 =  
the_channels_you_want_plot_6 = 
the_channels_you_want_plot_7 = 
the_channels_you_want_plot_8 = 
the_channels_you_want_plot_9 = 
the_channels_you_want_plot_10 = 
the_channels_you_want_plot_11 = 
the_channels_you_want_plot_12 = 


##################################################################################################################################################################################################################
##################################################################################################################################################################################################################
##################################################################################################################################################################################################################

whole_day_seconds = 60*60*24
whole_day_samples = whole_day_seconds/your_sampling_period 
heat = heatmap_period_you_want/your_sampling_period


delta_day =last_day - firth_day
text_list = glob.glob('*.txt')
print(text_list)
print(text_list[0])
dataraw = pd.read_table(text_list[0],header=None)



def raw_slice(dataraw):
    global kara_list
    kara_list = []
    if the_numbers_of_the_channels_you_want_delete == 0:
      for i in range(int(whole_day_samples*(firth_day-1))+1,int(whole_day_samples*(last_day)+1),1): 
              datai = dataraw.iloc[i*17-1,10:26]
              print(datai)
              datai_np = datai.values.tolist()
               #list_sum = data_sum.values.tolist()
               #print(list_sum)
              kara_list = kara_list + datai_np 
    else:
      for i in range(int(whole_day_samples*(firth_day-1)),int(whole_day_samples*(last_day)+1),1):
      #for i in range(1,31,1):
          
          datai = dataraw.iloc[i*17-1,[int(the_channels_you_want_plot_1 + 9),
                                            int(the_channels_you_want_plot_2 + 9),
                                            int(the_channels_you_want_plot_3 + 9),
                                            int(the_channels_you_want_plot_4 + 9),
                                            int(the_channels_you_want_plot_5 + 9),
                                            int(the_channels_you_want_plot_6 + 9),
                                            int(the_channels_you_want_plot_7 + 9),
                                            int(the_channels_you_want_plot_8 + 9),
                                            int(the_channels_you_want_plot_9 + 9)，
                                            int(the_channels_you_want_plot_10 + 9),
                                            int(the_channels_you_want_plot_11 + 9)，
                                            int(the_channels_you_want_plot_12 + 9)     ]]
               
          print(datai)
          datai_np = datai.values.tolist()
               #list_sum = data_sum.values.tolist()
               #print(list_sum)
          kara_list = kara_list + datai_np 
   
    
      print(kara_list)    
      arr_np = np.array(kara_list)
      kara_list_len = len(kara_list)
      print(kara_list_len)
      global kara_list_re
      kara_list_re = arr_np.reshape([int(kara_list_len/int(16-the_numbers_of_the_channels_you_want_delete)),
                                     int(16-the_numbers_of_the_channels_you_want_delete)])
      return kara_list_re

re = raw_slice(dataraw)





shushu = []


def re_counts(re):
#for j in range(1,1440+1,1):
    for j in range(1,int((delta_day+1)*whole_day_seconds/heatmap_period_you_want+1),1):
        npj = re[int((j-1)*heat):int(j*heat),:]
        print(npj)
    
        c1 = np.count_nonzero(npj == 1, axis=0)
        c2 = np.count_nonzero(npj == 2, axis=0)
        c3 = np.count_nonzero(npj == 3, axis=0)
        c4 = np.count_nonzero(npj == 4, axis=0)
        c5 = np.count_nonzero(npj == 5, axis=0)
        c6 = np.count_nonzero(npj == 6, axis=0)
        c7 = np.count_nonzero(npj == 7, axis=0)
        c8 = np.count_nonzero(npj == 8, axis=0)
        c9 = np.count_nonzero(npj == 9, axis=0)
        c10 = np.count_nonzero(npj == 10, axis=0)
        c11 = np.count_nonzero(npj == 11, axis=0)
        c12 = np.count_nonzero(npj == 12, axis=0)
        c13 = np.count_nonzero(npj == 13, axis=0)
        c14 = np.count_nonzero(npj == 14, axis=0)
        c15 = np.count_nonzero(npj == 15, axis=0)
        c16 = np.count_nonzero(npj == 16, axis=0)
        c17 = np.count_nonzero(npj == 17, axis=0)
    

    
        shushu.extend([c1.sum(),c2.sum(),c3.sum(),
                       c4.sum(),c5.sum(),c6.sum(),       
                       c7.sum(),c8.sum(),c9.sum(),  
                       c10.sum(),c11.sum(),c12.sum(), 
                      c13.sum(),c14.sum(),c15.sum(), 
                      c16.sum(),c17.sum()
                   
                       ])
        print(shushu)
 
    
    print(shushu)
    global shushu_np,shushu_np_re,shushu_np_re_df
    shushu_np = np.array(shushu)
    shushu_np_re = shushu_np.reshape([int(len(shushu_np)/17),17])
    #shushu_np_re = shushu_np.reshape([17,int(len(shushu_np)/17)])
    print(shushu_np_re)
    shushu_np_re_df = pd.DataFrame(shushu_np_re)
    return(shushu_np_re_df)

heatmap = re_counts(re)







#re = raw_slice(dataraw)



fig=plt.figure(figsize=(24,8))
sns.heatmap(heatmap.T,vmin=heatmap_vmin,vmax=heatmap_vmax,cmap="jet")
plt.savefig('multi__'+'.png')

# %%
##11匹
import numpy as np
import pyedflib
import matplotlib.pyplot as plt
import numpy as np
from numpy.fft import fftn, ifftn, fftfreq
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import sqlalchemy
from matplotlib.ticker import ScalarFormatter
import sqlalchemy
from matplotlib.ticker import ScalarFormatter
from scipy.fftpack import fft, ifft
import os
import glob
from sklearn.preprocessing import MinMaxScaler


'''
fill the number of days you want to polt
for example :
firth_day = 1
last_day = 3
your_sampling_period = 2
heatmap_period_you_want = 60
numbers_of_flies = 16
heatmap_vmax = 200
heatmap_vmin = 1
'''


firth_day = 1
last_day = 4
your_sampling_period = 2
heatmap_period_you_want = 60
numbers_of_flies = 16
heatmap_vmax = 80
heatmap_vmin = 1
the_numbers_of_the_channels_you_want_delete = 5

'''
if you don't want delete any channels,
you should not fill thoes followig equals
'''

the_channels_you_want_plot_1 = 
the_channels_you_want_plot_2 = 
the_channels_you_want_plot_3 = 
the_channels_you_want_plot_4 = 
the_channels_you_want_plot_5 =  
the_channels_you_want_plot_6 = 
the_channels_you_want_plot_7 = 
the_channels_you_want_plot_8 = 
the_channels_you_want_plot_9 = 
the_channels_you_want_plot_10 = 
the_channels_you_want_plot_11 = 



##################################################################################################################################################################################################################
##################################################################################################################################################################################################################
##################################################################################################################################################################################################################

whole_day_seconds = 60*60*24
whole_day_samples = whole_day_seconds/your_sampling_period 
heat = heatmap_period_you_want/your_sampling_period


delta_day =last_day - firth_day
text_list = glob.glob('*.txt')
print(text_list)
print(text_list[0])
dataraw = pd.read_table(text_list[0],header=None)



def raw_slice(dataraw):
    global kara_list
    kara_list = []
    if the_numbers_of_the_channels_you_want_delete == 0:
      for i in range(int(whole_day_samples*(firth_day-1))+1,int(whole_day_samples*(last_day)+1),1): 
              datai = dataraw.iloc[i*17-1,10:26]
              print(datai)
              datai_np = datai.values.tolist()
               #list_sum = data_sum.values.tolist()
               #print(list_sum)
              kara_list = kara_list + datai_np 
    else:
      for i in range(int(whole_day_samples*(firth_day-1)),int(whole_day_samples*(last_day)+1),1):
      #for i in range(1,31,1):
          
          datai = dataraw.iloc[i*17-1,[int(the_channels_you_want_plot_1 + 9),
                                            int(the_channels_you_want_plot_2 + 9),
                                            int(the_channels_you_want_plot_3 + 9),
                                            int(the_channels_you_want_plot_4 + 9),
                                            int(the_channels_you_want_plot_5 + 9),
                                            int(the_channels_you_want_plot_6 + 9),
                                            int(the_channels_you_want_plot_7 + 9),
                                            int(the_channels_you_want_plot_8 + 9),
                                            int(the_channels_you_want_plot_9 + 9)，
                                            int(the_channels_you_want_plot_10 + 9),
                                            int(the_channels_you_want_plot_11 + 9)     ]]
               
          print(datai)
          datai_np = datai.values.tolist()
               #list_sum = data_sum.values.tolist()
               #print(list_sum)
          kara_list = kara_list + datai_np 
   
    
      print(kara_list)    
      arr_np = np.array(kara_list)
      kara_list_len = len(kara_list)
      print(kara_list_len)
      global kara_list_re
      kara_list_re = arr_np.reshape([int(kara_list_len/int(16-the_numbers_of_the_channels_you_want_delete)),
                                     int(16-the_numbers_of_the_channels_you_want_delete)])
      return kara_list_re

re = raw_slice(dataraw)





shushu = []


def re_counts(re):
#for j in range(1,1440+1,1):
    for j in range(1,int((delta_day+1)*whole_day_seconds/heatmap_period_you_want+1),1):
        npj = re[int((j-1)*heat):int(j*heat),:]
        print(npj)
    
        c1 = np.count_nonzero(npj == 1, axis=0)
        c2 = np.count_nonzero(npj == 2, axis=0)
        c3 = np.count_nonzero(npj == 3, axis=0)
        c4 = np.count_nonzero(npj == 4, axis=0)
        c5 = np.count_nonzero(npj == 5, axis=0)
        c6 = np.count_nonzero(npj == 6, axis=0)
        c7 = np.count_nonzero(npj == 7, axis=0)
        c8 = np.count_nonzero(npj == 8, axis=0)
        c9 = np.count_nonzero(npj == 9, axis=0)
        c10 = np.count_nonzero(npj == 10, axis=0)
        c11 = np.count_nonzero(npj == 11, axis=0)
        c12 = np.count_nonzero(npj == 12, axis=0)
        c13 = np.count_nonzero(npj == 13, axis=0)
        c14 = np.count_nonzero(npj == 14, axis=0)
        c15 = np.count_nonzero(npj == 15, axis=0)
        c16 = np.count_nonzero(npj == 16, axis=0)
        c17 = np.count_nonzero(npj == 17, axis=0)
    

    
        shushu.extend([c1.sum(),c2.sum(),c3.sum(),
                       c4.sum(),c5.sum(),c6.sum(),       
                       c7.sum(),c8.sum(),c9.sum(),  
                       c10.sum(),c11.sum(),c12.sum(), 
                      c13.sum(),c14.sum(),c15.sum(), 
                      c16.sum(),c17.sum()
                   
                       ])
        print(shushu)
 
    
    print(shushu)
    global shushu_np,shushu_np_re,shushu_np_re_df
    shushu_np = np.array(shushu)
    shushu_np_re = shushu_np.reshape([int(len(shushu_np)/17),17])
    #shushu_np_re = shushu_np.reshape([17,int(len(shushu_np)/17)])
    print(shushu_np_re)
    shushu_np_re_df = pd.DataFrame(shushu_np_re)
    return(shushu_np_re_df)

heatmap = re_counts(re)







#re = raw_slice(dataraw)



fig=plt.figure(figsize=(24,8))
sns.heatmap(heatmap.T,vmin=heatmap_vmin,vmax=heatmap_vmax,cmap="jet")
plt.savefig('multi__'+'.png')

# %%
##10匹
import numpy as np
import pyedflib
import matplotlib.pyplot as plt
import numpy as np
from numpy.fft import fftn, ifftn, fftfreq
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import sqlalchemy
from matplotlib.ticker import ScalarFormatter
import sqlalchemy
from matplotlib.ticker import ScalarFormatter
from scipy.fftpack import fft, ifft
import os
import glob
from sklearn.preprocessing import MinMaxScaler


'''
fill the number of days you want to polt
for example :
firth_day = 1
last_day = 3
your_sampling_period = 2
heatmap_period_you_want = 60
numbers_of_flies = 16
heatmap_vmax = 200
heatmap_vmin = 1
'''


firth_day = 1
last_day = 4
your_sampling_period = 2
heatmap_period_you_want = 60
numbers_of_flies = 16
heatmap_vmax = 80
heatmap_vmin = 1
the_numbers_of_the_channels_you_want_delete = 6

'''
if you don't want delete any channels,
you should not fill thoes followig equals
'''

the_channels_you_want_plot_1 = 
the_channels_you_want_plot_2 = 
the_channels_you_want_plot_3 = 
the_channels_you_want_plot_4 = 
the_channels_you_want_plot_5 =  
the_channels_you_want_plot_6 = 
the_channels_you_want_plot_7 = 
the_channels_you_want_plot_8 = 
the_channels_you_want_plot_9 = 
the_channels_you_want_plot_10 = 



##################################################################################################################################################################################################################
##################################################################################################################################################################################################################
##################################################################################################################################################################################################################

whole_day_seconds = 60*60*24
whole_day_samples = whole_day_seconds/your_sampling_period 
heat = heatmap_period_you_want/your_sampling_period


delta_day =last_day - firth_day
text_list = glob.glob('*.txt')
print(text_list)
print(text_list[0])
dataraw = pd.read_table(text_list[0],header=None)



def raw_slice(dataraw):
    global kara_list
    kara_list = []
    if the_numbers_of_the_channels_you_want_delete == 0:
      for i in range(int(whole_day_samples*(firth_day-1))+1,int(whole_day_samples*(last_day)+1),1): 
              datai = dataraw.iloc[i*17-1,10:26]
              print(datai)
              datai_np = datai.values.tolist()
               #list_sum = data_sum.values.tolist()
               #print(list_sum)
              kara_list = kara_list + datai_np 
    else:
      for i in range(int(whole_day_samples*(firth_day-1)),int(whole_day_samples*(last_day)+1),1):
      #for i in range(1,31,1):
          
          datai = dataraw.iloc[i*17-1,[int(the_channels_you_want_plot_1 + 9),
                                            int(the_channels_you_want_plot_2 + 9),
                                            int(the_channels_you_want_plot_3 + 9),
                                            int(the_channels_you_want_plot_4 + 9),
                                            int(the_channels_you_want_plot_5 + 9),
                                            int(the_channels_you_want_plot_6 + 9),
                                            int(the_channels_you_want_plot_7 + 9),
                                            int(the_channels_you_want_plot_8 + 9),
                                            int(the_channels_you_want_plot_9 + 9)，
                                            int(the_channels_you_want_plot_10 + 9)     ]]
               
          print(datai)
          datai_np = datai.values.tolist()
               #list_sum = data_sum.values.tolist()
               #print(list_sum)
          kara_list = kara_list + datai_np 
   
    
      print(kara_list)    
      arr_np = np.array(kara_list)
      kara_list_len = len(kara_list)
      print(kara_list_len)
      global kara_list_re
      kara_list_re = arr_np.reshape([int(kara_list_len/int(16-the_numbers_of_the_channels_you_want_delete)),
                                     int(16-the_numbers_of_the_channels_you_want_delete)])
      return kara_list_re

re = raw_slice(dataraw)





shushu = []


def re_counts(re):
#for j in range(1,1440+1,1):
    for j in range(1,int((delta_day+1)*whole_day_seconds/heatmap_period_you_want+1),1):
        npj = re[int((j-1)*heat):int(j*heat),:]
        print(npj)
    
        c1 = np.count_nonzero(npj == 1, axis=0)
        c2 = np.count_nonzero(npj == 2, axis=0)
        c3 = np.count_nonzero(npj == 3, axis=0)
        c4 = np.count_nonzero(npj == 4, axis=0)
        c5 = np.count_nonzero(npj == 5, axis=0)
        c6 = np.count_nonzero(npj == 6, axis=0)
        c7 = np.count_nonzero(npj == 7, axis=0)
        c8 = np.count_nonzero(npj == 8, axis=0)
        c9 = np.count_nonzero(npj == 9, axis=0)
        c10 = np.count_nonzero(npj == 10, axis=0)
        c11 = np.count_nonzero(npj == 11, axis=0)
        c12 = np.count_nonzero(npj == 12, axis=0)
        c13 = np.count_nonzero(npj == 13, axis=0)
        c14 = np.count_nonzero(npj == 14, axis=0)
        c15 = np.count_nonzero(npj == 15, axis=0)
        c16 = np.count_nonzero(npj == 16, axis=0)
        c17 = np.count_nonzero(npj == 17, axis=0)
    

    
        shushu.extend([c1.sum(),c2.sum(),c3.sum(),
                       c4.sum(),c5.sum(),c6.sum(),       
                       c7.sum(),c8.sum(),c9.sum(),  
                       c10.sum(),c11.sum(),c12.sum(), 
                      c13.sum(),c14.sum(),c15.sum(), 
                      c16.sum(),c17.sum()
                   
                       ])
        print(shushu)
 
    
    print(shushu)
    global shushu_np,shushu_np_re,shushu_np_re_df
    shushu_np = np.array(shushu)
    shushu_np_re = shushu_np.reshape([int(len(shushu_np)/17),17])
    #shushu_np_re = shushu_np.reshape([17,int(len(shushu_np)/17)])
    print(shushu_np_re)
    shushu_np_re_df = pd.DataFrame(shushu_np_re)
    return(shushu_np_re_df)

heatmap = re_counts(re)







#re = raw_slice(dataraw)



fig=plt.figure(figsize=(24,8))
sns.heatmap(heatmap.T,vmin=heatmap_vmin,vmax=heatmap_vmax,cmap="jet")
plt.savefig('multi__'+'.png')

# %%
##9匹
import numpy as np
import pyedflib
import matplotlib.pyplot as plt
import numpy as np
from numpy.fft import fftn, ifftn, fftfreq
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import sqlalchemy
from matplotlib.ticker import ScalarFormatter
import sqlalchemy
from matplotlib.ticker import ScalarFormatter
from scipy.fftpack import fft, ifft
import os
import glob
from sklearn.preprocessing import MinMaxScaler


'''
fill the number of days you want to polt
for example :
firth_day = 1
last_day = 3
your_sampling_period = 2
heatmap_period_you_want = 60
numbers_of_flies = 16
heatmap_vmax = 200
heatmap_vmin = 1
'''


firth_day = 1
last_day = 4
your_sampling_period = 2
heatmap_period_you_want = 60
numbers_of_flies = 16
heatmap_vmax = 80
heatmap_vmin = 1
the_numbers_of_the_channels_you_want_delete = 7

'''
if you don't want delete any channels,
you should not fill thoes followig equals
'''

the_channels_you_want_plot_1 = 2
the_channels_you_want_plot_2 = 3
the_channels_you_want_plot_3 = 4
the_channels_you_want_plot_4 = 5
the_channels_you_want_plot_5 = 6
the_channels_you_want_plot_6 = 7
the_channels_you_want_plot_7 = 8
the_channels_you_want_plot_8 = 9
the_channels_you_want_plot_9 = 12




##################################################################################################################################################################################################################
##################################################################################################################################################################################################################
##################################################################################################################################################################################################################

whole_day_seconds = 60*60*24
whole_day_samples = whole_day_seconds/your_sampling_period 
heat = heatmap_period_you_want/your_sampling_period


delta_day =last_day - firth_day
text_list = glob.glob('*.txt')
print(text_list)
print(text_list[0])
dataraw = pd.read_table(text_list[0],header=None)



def raw_slice(dataraw):
    global kara_list
    kara_list = []
    if the_numbers_of_the_channels_you_want_delete == 0:
      for i in range(int(whole_day_samples*(firth_day-1))+1,int(whole_day_samples*(last_day)+1),1): 
              datai = dataraw.iloc[i*17-1,10:26]
              print(datai)
              datai_np = datai.values.tolist()
               #list_sum = data_sum.values.tolist()
               #print(list_sum)
              kara_list = kara_list + datai_np 
    else:
      for i in range(int(whole_day_samples*(firth_day-1)),int(whole_day_samples*(last_day)+1),1):
      #for i in range(1,31,1):
          
          datai = dataraw.iloc[i*17-1,[int(the_channels_you_want_plot_1 + 9),
                                            int(the_channels_you_want_plot_2 + 9),
                                            int(the_channels_you_want_plot_3 + 9),
                                            int(the_channels_you_want_plot_4 + 9),
                                            int(the_channels_you_want_plot_5 + 9),
                                            int(the_channels_you_want_plot_6 + 9),
                                            int(the_channels_you_want_plot_7 + 9),
                                            int(the_channels_you_want_plot_8 + 9),
                                            int(the_channels_you_want_plot_9 + 9)     ]]
               
          print(datai)
          datai_np = datai.values.tolist()
               #list_sum = data_sum.values.tolist()
               #print(list_sum)
          kara_list = kara_list + datai_np 
   
    
      print(kara_list)    
      arr_np = np.array(kara_list)
      kara_list_len = len(kara_list)
      print(kara_list_len)
      global kara_list_re
      kara_list_re = arr_np.reshape([int(kara_list_len/int(16-the_numbers_of_the_channels_you_want_delete)),
                                     int(16-the_numbers_of_the_channels_you_want_delete)])
      return kara_list_re

re = raw_slice(dataraw)





shushu = []


def re_counts(re):
#for j in range(1,1440+1,1):
    for j in range(1,int((delta_day+1)*whole_day_seconds/heatmap_period_you_want+1),1):
        npj = re[int((j-1)*heat):int(j*heat),:]
        print(npj)
    
        c1 = np.count_nonzero(npj == 1, axis=0)
        c2 = np.count_nonzero(npj == 2, axis=0)
        c3 = np.count_nonzero(npj == 3, axis=0)
        c4 = np.count_nonzero(npj == 4, axis=0)
        c5 = np.count_nonzero(npj == 5, axis=0)
        c6 = np.count_nonzero(npj == 6, axis=0)
        c7 = np.count_nonzero(npj == 7, axis=0)
        c8 = np.count_nonzero(npj == 8, axis=0)
        c9 = np.count_nonzero(npj == 9, axis=0)
        c10 = np.count_nonzero(npj == 10, axis=0)
        c11 = np.count_nonzero(npj == 11, axis=0)
        c12 = np.count_nonzero(npj == 12, axis=0)
        c13 = np.count_nonzero(npj == 13, axis=0)
        c14 = np.count_nonzero(npj == 14, axis=0)
        c15 = np.count_nonzero(npj == 15, axis=0)
        c16 = np.count_nonzero(npj == 16, axis=0)
        c17 = np.count_nonzero(npj == 17, axis=0)
    

    
        shushu.extend([c1.sum(),c2.sum(),c3.sum(),
                       c4.sum(),c5.sum(),c6.sum(),       
                       c7.sum(),c8.sum(),c9.sum(),  
                       c10.sum(),c11.sum(),c12.sum(), 
                      c13.sum(),c14.sum(),c15.sum(), 
                      c16.sum(),c17.sum()
                   
                       ])
        print(shushu)
 
    
    print(shushu)
    global shushu_np,shushu_np_re,shushu_np_re_df
    shushu_np = np.array(shushu)
    shushu_np_re = shushu_np.reshape([int(len(shushu_np)/17),17])
    #shushu_np_re = shushu_np.reshape([17,int(len(shushu_np)/17)])
    print(shushu_np_re)
    shushu_np_re_df = pd.DataFrame(shushu_np_re)
    return(shushu_np_re_df)

heatmap = re_counts(re)







#re = raw_slice(dataraw)



fig=plt.figure(figsize=(24,8))
sns.heatmap(heatmap.T,vmin=heatmap_vmin,vmax=heatmap_vmax,cmap="jet")
plt.savefig('multi__'+'.png')

# %%
##9匹
import numpy as np
import pyedflib
import matplotlib.pyplot as plt
import numpy as np
from numpy.fft import fftn, ifftn, fftfreq
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import sqlalchemy
from matplotlib.ticker import ScalarFormatter
import sqlalchemy
from matplotlib.ticker import ScalarFormatter
from scipy.fftpack import fft, ifft
import os
import glob
from sklearn.preprocessing import MinMaxScaler


'''
fill the number of days you want to polt
for example :
firth_day = 1
last_day = 3
your_sampling_period = 2
heatmap_period_you_want = 60
numbers_of_flies = 16
heatmap_vmax = 200
heatmap_vmin = 1
'''


firth_day = 1
last_day = 4
your_sampling_period = 2
heatmap_period_you_want = 60
numbers_of_flies = 16
heatmap_vmax = 80
heatmap_vmin = 1
the_numbers_of_the_channels_you_want_delete = 8

'''
if you don't want delete any channels,
you should not fill thoes followig equals
'''

the_channels_you_want_plot_1 = 2
the_channels_you_want_plot_2 = 3
the_channels_you_want_plot_3 = 4
the_channels_you_want_plot_4 = 5
the_channels_you_want_plot_5 = 6
the_channels_you_want_plot_6 = 7
the_channels_you_want_plot_7 = 8
the_channels_you_want_plot_8 = 9





##################################################################################################################################################################################################################
##################################################################################################################################################################################################################
##################################################################################################################################################################################################################

whole_day_seconds = 60*60*24
whole_day_samples = whole_day_seconds/your_sampling_period 
heat = heatmap_period_you_want/your_sampling_period


delta_day =last_day - firth_day
text_list = glob.glob('*.txt')
print(text_list)
print(text_list[0])
dataraw = pd.read_table(text_list[0],header=None)



def raw_slice(dataraw):
    global kara_list
    kara_list = []
    if the_numbers_of_the_channels_you_want_delete == 0:
      for i in range(int(whole_day_samples*(firth_day-1))+1,int(whole_day_samples*(last_day)+1),1): 
              datai = dataraw.iloc[i*17-1,10:26]
              print(datai)
              datai_np = datai.values.tolist()
               #list_sum = data_sum.values.tolist()
               #print(list_sum)
              kara_list = kara_list + datai_np 
    else:
      for i in range(int(whole_day_samples*(firth_day-1)),int(whole_day_samples*(last_day)+1),1):
      #for i in range(1,31,1):
          
          datai = dataraw.iloc[i*17-1,[int(the_channels_you_want_plot_1 + 9),
                                            int(the_channels_you_want_plot_2 + 9),
                                            int(the_channels_you_want_plot_3 + 9),
                                            int(the_channels_you_want_plot_4 + 9),
                                            int(the_channels_you_want_plot_5 + 9),
                                            int(the_channels_you_want_plot_6 + 9),
                                            int(the_channels_you_want_plot_7 + 9),
                                            int(the_channels_you_want_plot_8 + 9)
                                                 ]]
               
          print(datai)
          datai_np = datai.values.tolist()
               #list_sum = data_sum.values.tolist()
               #print(list_sum)
          kara_list = kara_list + datai_np 
   
    
      print(kara_list)    
      arr_np = np.array(kara_list)
      kara_list_len = len(kara_list)
      print(kara_list_len)
      global kara_list_re
      kara_list_re = arr_np.reshape([int(kara_list_len/int(16-the_numbers_of_the_channels_you_want_delete)),
                                     int(16-the_numbers_of_the_channels_you_want_delete)])
      return kara_list_re

re = raw_slice(dataraw)





shushu = []


def re_counts(re):
#for j in range(1,1440+1,1):
    for j in range(1,int((delta_day+1)*whole_day_seconds/heatmap_period_you_want+1),1):
        npj = re[int((j-1)*heat):int(j*heat),:]
        print(npj)
    
        c1 = np.count_nonzero(npj == 1, axis=0)
        c2 = np.count_nonzero(npj == 2, axis=0)
        c3 = np.count_nonzero(npj == 3, axis=0)
        c4 = np.count_nonzero(npj == 4, axis=0)
        c5 = np.count_nonzero(npj == 5, axis=0)
        c6 = np.count_nonzero(npj == 6, axis=0)
        c7 = np.count_nonzero(npj == 7, axis=0)
        c8 = np.count_nonzero(npj == 8, axis=0)
        c9 = np.count_nonzero(npj == 9, axis=0)
        c10 = np.count_nonzero(npj == 10, axis=0)
        c11 = np.count_nonzero(npj == 11, axis=0)
        c12 = np.count_nonzero(npj == 12, axis=0)
        c13 = np.count_nonzero(npj == 13, axis=0)
        c14 = np.count_nonzero(npj == 14, axis=0)
        c15 = np.count_nonzero(npj == 15, axis=0)
        c16 = np.count_nonzero(npj == 16, axis=0)
        c17 = np.count_nonzero(npj == 17, axis=0)
    

    
        shushu.extend([c1.sum(),c2.sum(),c3.sum(),
                       c4.sum(),c5.sum(),c6.sum(),       
                       c7.sum(),c8.sum(),c9.sum(),  
                       c10.sum(),c11.sum(),c12.sum(), 
                      c13.sum(),c14.sum(),c15.sum(), 
                      c16.sum(),c17.sum()
                   
                       ])
        print(shushu)
 
    
    print(shushu)
    global shushu_np,shushu_np_re,shushu_np_re_df
    shushu_np = np.array(shushu)
    shushu_np_re = shushu_np.reshape([int(len(shushu_np)/17),17])
    #shushu_np_re = shushu_np.reshape([17,int(len(shushu_np)/17)])
    print(shushu_np_re)
    shushu_np_re_df = pd.DataFrame(shushu_np_re)
    return(shushu_np_re_df)

heatmap = re_counts(re)







#re = raw_slice(dataraw)



fig=plt.figure(figsize=(24,8))
sns.heatmap(heatmap.T,vmin=heatmap_vmin,vmax=heatmap_vmax,cmap="jet")
plt.savefig('multi__'+'.png')
